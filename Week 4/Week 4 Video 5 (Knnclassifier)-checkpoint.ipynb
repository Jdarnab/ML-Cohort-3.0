# %%
from sklearn import datasets, linear_model
import numpy as np 
import matplotlib.pyplot as plt 
#from sklearn.neighbors import KNeighborsClassifier 
iris= datasets.load_iris () 
iris_X=iris.data [:, np.newaxis,2]
iris_X_train = iris_X [ :-30]
iris_X_test = iris_X [ -30:] 
iris_Y_train = iris.target [:-30]
iris_Y_test= iris.target [-30:] 
model= linear_model.LinearRegression ()
model.fit (iris_X_train, iris_Y_train )
iris_Y_predicted = model.predict ( iris_X_test ) 
plt.scatter ( iris_X_test, iris_Y_test, linewidth = 1, label = 'Actual')
plt.plot (iris_Y_test, iris_Y_predicted, linewidth =2, color= 'r', label = 'Predicted')
plt.legend (loc='upper right')
plt.show ()

#features= iris.data
#lebels= iris.target 
#print (features[0], lebels [0])
#print (features )
#print (lebels)
#print (iris.DESCR)]

# %%
from sklearn import datasets
from sklearn.neighbors import KNeighborsClassifier
iris= datasets.load_iris ()
features= iris.data
lebels= iris.target
#training the classifier 
clf= KNeighborsClassifier ()
clf.fit (features, lebels) 
prediction = clf.predict ( [[3.1,3.0,2,5]])
print (prediction) 
#print (features , lebels)
#print (iris.DESCR)
# Out:
# [1]
